# %% [markdown]
# #1.Mount Drive

# %% [raw]
# from google.colab import drive
# drive.mount('/gdrive')
#
# !ls -al 'data'

# %% [markdown]
# #2. Korean Characters

# %% [raw]
# # Colab or Ubuntu
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
# 파이썬 시각화 패키지 불러오기
import matplotlib.pyplot as plt
# %matplotlib inline

# 사용자 운영체제 확인
import os
os.name

# 운영체제별 한글 폰트 설정
if os.name == 'posix': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif os.name == 'nt': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# 런타임 - 런타임 다시 시작
#
# matplotlib의 폰트를 NanumGothic 폰트로 지정

# %%
#  차트 설정
# import matplotlib.font_manager as fm 
# fontprop =fm.FontProperties(fname="fonts/malgun.ttf")
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

# %%
# %%html
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>
# Out:
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>

# %% [markdown]
# #3. Load Data

# %%
file = 'data/data_2020.csv'
data = pd.read_csv(file)

# %%
data.head()
# Out:
#        집계일자  집계시  출발영업소코드  도착영업소코드  통행시간  요일
# 0  20200101    4      101      105   637   2
# 1  20200101    4      101      105   773   2
# 2  20200101    4      101      105   762   2
# 3  20200101    4      101      105   746   2
# 4  20200101    4      101      105   875   2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152870 entries, 0 to 152869
# Data columns (total 6 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   집계일자     152870 non-null  int64
#  1   집계시      152870 non-null  int64
#  2   출발영업소코드  152870 non-null  int64
#  3   도착영업소코드  152870 non-null  int64
#  4   통행시간     152870 non-null  int64
#  5   요일       152870 non-null  int64
# dtypes: int64(6)
# memory usage: 7.0 MB

# %% [markdown]
# #4. Histplot

# %%
#101,서울 105,기흥 110,목천 115,대전 120,황간 125,남구미 130,동김천 135,경주 140,부산
labels = ['기흥', '목천', '대전', '황간', '남구미', '동김천', '경주', '부산']

# %%
data_statistics = data[data['도착영업소코드'] == 130]['통행시간'].describe()

# %%
data_statistics
# Out:
# count     7793.000000
# mean      9142.913255
# std       1983.333360
# min       5736.000000
# 25%       8233.000000
# 50%       8898.000000
# 75%       9619.000000
# max      52762.000000
# Name: 통행시간, dtype: float64

# %%
# Configure figure size
plt.figure(figsize=(20,10))
sns.set(style="ticks", palette="pastel")
# Draw a nested boxplot to show Pace by Gender
sns.boxplot(x="요일", y="통행시간",
            data=data)
plt.show()

# %%
# 필요한 패키지와 라이브러리 가져옴
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] =False

# %%
# 폰트 설치 위치

print('버전: ', mpl.__version__)
print('설치 위치: ', mpl.__file__)
print('설정 위치: ', mpl.get_configdir())
print('캐시 위치: ', mpl.get_cachedir())
print('설정 파일 위치: ', mpl.matplotlib_fname())
# Out:
# 버전:  3.4.2
# 설치 위치:  d:\encore-4team\step3 데이터 전처리\project-yfinance\venv\lib\site-packages\matplotlib\__init__.py
# 설정 위치:  C:\Users\inhwa\.matplotlib
# 캐시 위치:  C:\Users\inhwa\.matplotlib
# 설정 파일 위치:  d:\encore-4team\step3 데이터 전처리\project-yfinance\venv\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
# 설치된 폰트 리스크
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# ttf 폰트 전체 갯수
print(len(font_list))
# Out:
# 814

# %%
for i in font_list:
    if 'Nanum' in i:
        print(i)
# Out:
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumGothicLight.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumGothicBold.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumGothicEcoBold.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumSquare_acL.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumGothicExtraBold.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumSquareEB.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumSquareB.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumGothicEco.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumSquareR.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumGothicEcoExtraBold.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumSquareL.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumSquare_0.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumSquare.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumGothic.ttf
# C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumSquare_acR.ttf

# %%
# font properties
path = r'C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumGothicBold.ttf'
fontprop = fm.FontProperties(fname=path, size=18)

# Configure figure size
plt.figure(figsize=(20,10))
plt.xlabel('', fontproperties=fontprop)
plt.ylabel('', fontproperties=fontprop)

sns.set(style="ticks", palette="pastel")
# Draw a nested boxplot to show Pace by Gender
sns.boxplot(x="집계시", y="통행시간",
            data=data)
plt.show()

# %%
# 폰트 기본 설정 읽기

# size, family
print("# 설정 되어있는 폰트 사이즈")
print(plt.rcParams['font.size'])
print('# 설정 되어있는 폰트 글꼴')
print(plt.rcParams['font.family'])
# Out:
# # 설정 되어있는 폰트 사이즈
# 12.0
# # 설정 되어있는 폰트 글꼴
# ['sans-serif']

# %%
# 폰트 패밀리

from matplotlib import font_manager

font_fname = r'C:\Users\inhwa\AppData\Local\Microsoft\Windows\Fonts\NanumGothicBold.ttf'
font_family = font_manager.FontProperties(fname=font_fname).get_name()

print(font_family)
# Out:
# NanumGothic

# %%
# 전역 글꼴 설정

plt.rcParams["font.family"] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.size'] = 24.
plt.rcParams['xtick.labelsize'] = 12.
plt.rcParams['ytick.labelsize'] = 12.
plt.rcParams['axes.labelsize'] = 20.

print (plt.rcParams['font.family'] )
# Out:
# ['NanumGothic']

# %% [markdown]
# #5. Countplot

# %%
# Configure figure size
plt.figure(figsize=(20,10))
# Create histogram - Distribution Rate
data_destination = sns.countplot(data=data, x='도착영업소코드')
data_destination.set_xlabel('도착영업소코드',fontdict= {'size':16})
data_destination.set_ylabel('통행회수',fontdict= {'size':16})
data_destination.set_title('통행회수 by 도착영업소코드',fontsize=18)
plt.show()

# %%
# Configure figure size
plt.figure(figsize=(20,10))
# Create histogram - Distribution Rate
data_destination = sns.countplot(data=data, x='도착영업소코드', order= data['도착영업소코드'].value_counts().index)
data_destination.set_xlabel('도착영업소코드',fontdict= {'size':16})
data_destination.set_ylabel('통행회수',fontdict= {'size':16})
data_destination.set_title('통행회수 by 도착영업소코드',fontsize=18)
plt.show()

# %% [markdown]
# #6. Histogram

# %%
plt.figure(figsize=(20,10))
sns.histplot(data[data['도착영업소코드'] == 110]['통행시간'], color='green', label='목천')
sns.histplot(data[data['도착영업소코드'] == 125]['통행시간'], color='blue', label='남구미')
sns.histplot(data[data['도착영업소코드'] == 140]['통행시간'], color='red', label='부산')
plt.legend(title='도착영업소')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=data, x='통행시간', hue='도착영업소코드')
plt.show()
